# %%
import os


#获取文件地址
def get_filelist (dir, filelist):
    new_dir = dir
    if os.path.isfile(dir):
        filelist.append(dir)
    elif os.path.isdir(dir):
        for s in os.listdir(dir):
            new_dir = os.path.join(dir, s)
            get_filelist(new_dir, filelist)
    return filelist


def filelist_to_dataframe():


train_folder = "train"

train_list = get_filelist(train_folder, list())
train_list
# Out:
# ['train/aceb9c8c34ca78efea3f.csv',
#  'train/5c2103353c3b597cbc3a.csv',
#  'train/96f81a38cce0af5106fc.csv',
#  'train/7bd9af290551492d6850.csv',
#  'train/5fa4ac154d0e94bfa740.csv',
#  'train/b3fdc2ac48b41dfbee8a.csv',
#  'train/712bd72515a8bf7f350e.csv',
#  'train/1536b2a38077927c5ad1.csv',
#  'train/0538197e025d2e1c6e54.csv',
#  'train/e4cf94509450400baad5.csv',
#  'train/fd810bb1dc9b295034de.csv',
#  'train/677bcd7c54200025cbd4.csv',
#  'train/7698253bbd5a3cb6b964.csv',
#  'train/09171edb3d42f3fdf84e.csv',
#  'train/d37b0ea0165e8da7d5bd.csv',
#  'train/b5b10ed8a07e586d53e2.csv',
#  'train/c2229a5871911e8f3e7d.csv',
#  'train/52558c9a900cf80be98d.csv',
#  'train/3637658769eba73e3672.csv',
#  'train/dcd7f385eb2dbbe74d83.csv',
#  'train/c7aaa10fcd5e51da245f.csv',
#  'train/1bcc0db0520993d9614a.csv',
#  'train/2cb5694d72f332eff77b.csv',
#  'train/4bdb40bb989d451f74e1.csv',
#  'train/57a455cee285b8de59cb.csv',
#  'train/d6d5ed2275373deabf7f.csv',
#  'train/19b5534955a25e95608c.csv',
#  'train/4c55be7094be933c5d37.csv',
#  'train/29298325e89ec6854d85.csv',
#  'train/a8e25c9be4c46e0939e6.csv',
#  'train/e3a20a34ff6ea85e25db.csv',
#  'train/ae3ed0eb55cdace930b5.csv',
#  'train/56cd06ee43ca3cd56697.csv',
#  'train/ab5a07dd94b46d9237cc.csv',
#  'train/304cdd222345f28a0b02.csv',
#  'train/5b250bb330b946dd96b8.csv',
#  'train/c48e439fd63f5584ff31.csv',
#  'train/b9b495c1b5ea0bc9cce2.csv',
#  'train/20c582a4feb565e023d4.csv',
#  'train/49953bffba93bc323f2d.csv',
#  'train/93126e32eefd57207290.csv',
#  'train/347e8aaf1ef19e28ed8e.csv',
#  'train/dfd5723198387f1740ec.csv',
#  'train/e28105c77e572f39badf.csv',
#  'train/6beef8234e07f4c6e99f.csv',
#  'train/e782feda59ad6d4b99f8.csv',
#  'train/471b133e70ae8b321d21.csv',
#  'train/8b50779f8fed99a1bb3e.csv',
#  'train/d6edc58490f5bfe9da38.csv',
#  'train/f208dc672bfd5991dfec.csv',
#  'train/a25b97d64f5ffa306162.csv',
#  'train/132c50e9c3f6e9be6add.csv',
#  'train/6bd447968a5842a13537.csv',
#  'train/1897d63194cf1171588a.csv',
#  'train/dffb8e3f3aff6cf09c89.csv',
#  'train/953503344835e90ff332.csv',
#  'train/42ce63d929e43870d626.csv',
#  'train/bc11e57202feb139f1c0.csv',
#  'train/a95d823d7eab7afa9522.csv',
#  'train/68a2cf79ffec23fb1bae.csv',
#  'train/fb98732660815cb560f6.csv',
#  'train/192004b116307ac7b527.csv',
#  'train/2c607ce2e7bf54c7cc7c.csv',
#  'train/19fcda487519b8953b09.csv',
#  'train/2e4dbfa9a44a789e36cd.csv',
#  'train/cd4e25a48d04eb66a1d5.csv',
#  'train/bdf260e67623a66504fe.csv',
#  'train/48babcc23e4de6bf1a87.csv',
#  'train/088d4f86d9f9926886f3.csv',
#  'train/7706c5839cf30a61ff0c.csv',
#  'train/4a58d999d0d1d7166163.csv',
#  'train/de5d7628aced6b08c5bc.csv',
#  'train/6350ba579eead8d444d4.csv',
#  'train/7a5316aa2f74d0860063.csv',
#  'train/4c71a0a704dfdf86152d.csv',
#  'train/d121f681ad3df8178280.csv',
#  'train/166117afe300e56492b1.csv',
#  'train/1687133bd579ac7fcbf8.csv',
#  'train/6abed3eb8e2dab959ff8.csv',
#  'train/5cdbc9a3deecb12d081e.csv',
#  'train/2f2075a687f8169a5a69.csv',
#  'train/05459e25fd4595ae187d.csv',
#  'train/c08dc1a140653cfbc85c.csv',
#  'train/6c6d18d65bd5801a3b74.csv',
#  'train/e6c1046e9eb8e16e6a23.csv',
#  'train/0afc4f2d2a40214bc50b.csv',
#  'train/592ea9672cd566fbebcb.csv',
#  'train/e09cf228f354a2ea779d.csv',
#  'train/634497525d9bf4d26e82.csv',
#  'train/79ad02ab3ddb6a0a7ead.csv',
#  'train/e2875bfdc26c783f57e7.csv',
#  'train/1a1aff7eb38611aa7a1c.csv',
#  'train/050ddc66f0ba174dc837.csv',
#  'train/11c49fe0341a96c2fa90.csv',
#  'train/3772d37a4401c1069ea3.csv',
#  'train/eed6eef17f4a5576e060.csv',
#  'train/8378811267a07dfc6ffc.csv',
#  'train/08fe0617440b4b0532ff.csv',
#  'train/ab3ac6d3ab5ac92121ac.csv',
#  'train/e53394a0c695a9539c8f.csv',
#  'train/8ee237bf049676bababe.csv',
#  'train/554a8d7905f03e80ba92.csv',
#  'train/39f173458ef368e55549.csv',
#  'train/f3e718ceb99ca3424bd5.csv',
#  'train/2806813459c936443e98.csv',
#  'train/9b2bb80d2ed8cda9f944.csv',
#  'train/963755a6fea8a74feba6.csv',
#  'train/5e4deecc5084be8d73a1.csv',
#  'train/c301a5ba18b78b199b65.csv',
#  'train/c7a3c9814e17951e3787.csv',
#  'train/f28933ca0dd18add41f6.csv',
#  'train/48350eac19ee5de0ab13.csv',
#  'train/f742c76952e728ebcf78.csv',
#  'train/d7ca2ee282d5513aed6c.csv',
#  'train/85eb660217eee2175041.csv',
#  'train/af455034577c32c3b21d.csv',
#  'train/4ba8fe6807211e2e1a12.csv',
#  'train/cce2f0d0ed78527a08c2.csv',
#  'train/7374d039c7fc10e2a49f.csv',
#  'train/d9fe630f6b92fdbadb1b.csv',
#  'train/f04d80fe5e8b37ca7d55.csv',
#  'train/d3a52633b6f6d76a41d8.csv',
#  'train/65c13bb2db5c1e1fe3c6.csv',
#  'train/3ec187ac9790fc84ccc9.csv',
#  'train/30531f3b3ca2c7981497.csv',
#  'train/faa5d807b79b757e7760.csv',
#  'train/575a459a07bc3461f6d3.csv',
#  'train/912c8d562cc12b301cee.csv',
#  'train/776ff1a8d4e0cb1798ef.csv',
#  'train/d864c2c8fd7fc5f3b6ee.csv',
#  'train/0f17a8f78ad00a1c632c.csv',
#  'train/d6803b9c0a429d4ae751.csv',
#  'train/0b2f90e9a0908b0cd300.csv',
#  'train/545498c13eeaf7654d35.csv',
#  'train/f3bb1cb17fa3199b57ee.csv',
#  'train/996a4a843dd668854c89.csv',
#  'train/aceec7e51ba4cf1fe4db.csv',
#  'train/dca0b69affc5a90b45b1.csv',
#  'train/0f47a6d09e117b342ea8.csv',
#  'train/bf6bc73ab1c53d0128b8.csv',
#  'train/63371809fb023fa56268.csv',
#  'train/784db9968b4d62dea70d.csv',
#  'train/ff5b87a5e1d477ffee61.csv',
#  'train/fe22c69b313816ca81f8.csv',
#  'train/b50f6af5ded8a99cb779.csv',
#  'train/e0d6387c34ebeb46d25e.csv',
#  'train/552fa2765f3edaa5d2fd.csv',
#  'train/d9a646dc4b887185fc7f.csv',
#  'train/75aeaa71c06ba9345b07.csv',
#  'train/eb7c12321a09815d6c8e.csv',
#  'train/cefb4d0b8fa75923aad0.csv',
#  'train/e33b533394e6baa2cd00.csv',
#  'train/936e6a373cd110cf5b1d.csv',
#  'train/51cb793709e4abba64be.csv',
#  'train/cac3c473d4a6071ee522.csv',
#  'train/9b6a1b8a54eda591105c.csv',
#  'train/fa94788267c163b15f34.csv',
#  'train/f85aff1bdbcdd441dc89.csv',
#  'train/6a6193d81a92827dbe64.csv',
#  'train/14662470b3ba2574e89f.csv',
#  'train/89e2efab2f461d1ef01e.csv',
#  'train/6936fd79d5175060e35f.csv',
#  'train/4724bf89fc8874a6863a.csv',
#  'train/6f9c48125523b412c7b5.csv',
#  'train/5b1f445fa929a847c600.csv',
#  'train/6774cd1f687ce659cc5e.csv',
#  'train/1c96c819ab936960adbe.csv',
#  'train/d23fafe1a4d3d5e63197.csv',
#  'train/17f85263d3f078a1e985.csv',
#  'train/ad7e81ef4a70b45ad27e.csv',
#  'train/c1ad61a32bf51051f0f2.csv',
#  'train/981e8f83f8303df4643c.csv',
#  'train/9f8e5c24325cf761f58e.csv',
#  'train/a8e209d79e967bfc321f.csv',
#  'train/1b1859f1c8644905f5a5.csv',
#  'train/ae5a037c742f639928af.csv',
#  'train/7e12e9e62790baa04d81.csv',
#  'train/b0970387350723d3bd59.csv',
#  'train/a06963a069ce102d1fe2.csv',
#  'train/f2426387f5b950e4ac35.csv',
#  'train/254ce1c039d721ca7064.csv',
#  'train/d67371698a3aea11f382.csv',
#  'train/b4cfe35a490414cfe2cd.csv',
#  'train/5ff0017257347257eeca.csv',
#  'train/c64ba8edc0b87855aa8c.csv',
#  'train/ff31fed924dccf5b90c5.csv',
#  'train/f64143df3dd979288083.csv',
#  'train/24cd3f0020216e6dbe9c.csv',
#  'train/425a329c742b9d5723cc.csv',
#  'train/12f5447594f16b8345e8.csv',
#  'train/b8739df1ab21f97c1e2b.csv',
#  'train/21ecaedd5ec160499109.csv',
#  'train/5826f240287044261770.csv',
#  'train/e941b6ef88755414bc44.csv',
#  'train/de1b3b4bde455631f62b.csv',
#  'train/6d5e9a61773e2e03c592.csv',
#  'train/053e4f345a91ccb20189.csv',
#  'train/9df05109a65da8a8d62e.csv',
#  'train/6f15bc594e038f70c251.csv',
#  'train/753cdd8a751c3115778e.csv',
#  'train/dfd51a1b6ccb4ccf0c4b.csv',
#  'train/12de4ac5e19342dd9223.csv',
#  'train/2b29cbce1ce1742f0c54.csv',
#  'train/4c0ca9e226d099f11ce2.csv',
#  'train/b4d1eaa902420c621528.csv',
#  'train/b3f4c7a7da9ae1a601e1.csv',
#  'train/6d806655b2c0c5ed0f09.csv',
#  'train/ceb4b711d6788101a053.csv',
#  'train/ecc7c4ab3b4cf63db9f6.csv',
#  'train/cce54ca7d4f42fb1c617.csv',
#  'train/71aa3d1e81a2d2aa5f5c.csv',
#  'train/5aadfd81fbfcb411bebc.csv',
#  'train/114175f1e4fff7c15385.csv',
#  'train/25e2716f8cd3a7e7d1ef.csv',
#  'train/a1749524310e60c53e87.csv',
#  'train/9290046c18b1c3231cdc.csv',
#  'train/361976e4c45c82ab978d.csv',
#  'train/3fa0f14cd46d2bbd92ac.csv',
#  'train/7689511b21190cb4f89f.csv',
#  'train/8ba1a68c7c8d92d4b1d0.csv',
#  'train/8f651ee5e8699146a3f1.csv',
#  'train/104b6a62d2a224c9427d.csv',
#  'train/6657de720ccb5fd852e8.csv',
#  'train/44d96ac6ae4b0b472e2b.csv',
#  'train/8832eca160550afa98f2.csv',
#  'train/a99405ba8ae1e8d22afd.csv',
#  'train/05523fa4de251a7712cc.csv',
#  'train/5c4b5742f10d8a7d3ee6.csv',
#  'train/c18c88da4346d806e5a4.csv',
#  'train/726ffe0771622239088a.csv',
#  'train/91f05823d54144c139dd.csv',
#  'train/82bf5934ec257802478d.csv',
#  'train/add21805fe7389af0099.csv',
#  'train/1710e43e01d66ebd93b6.csv',
#  'train/b8e6aade4c840973a6d1.csv',
#  'train/1fdcaf441d38d9c05ff5.csv',
#  'train/22808545876f05025af5.csv',
#  'train/64eec279b461d4609641.csv',
#  'train/9d1b8735b6864920d564.csv',
#  'train/023f3b34ae4ae455a3a3.csv',
#  'train/2e3d403229d9ada3f979.csv',
#  'train/188f9b327332d7b2c7f9.csv',
#  'train/61011e26ebc4a4d6c716.csv',
#  'train/46254ad24585468938c2.csv',
#  'train/9de18ea906c40cf6fd15.csv',
#  'train/847b36c410cf4d700aa5.csv',
#  'train/13a66342895acc5e1db8.csv',
#  'train/99f479bcbebc6ff336a6.csv',
#  'train/172e6941bc0a08ad75af.csv',
#  'train/911fb73b6948fd59a2f3.csv',
#  'train/a8e0e928c5fdf85dbc9e.csv',
#  'train/8e5d858e2e0033d51377.csv',
#  'train/d7e5a125e7a70e73ba2c.csv',
#  'train/5b422aa0908cf2bc4ba5.csv',
#  'train/3c36dfd3c7d0ee39e239.csv',
#  'train/98152bd06d2f5fe78807.csv',
#  'train/3f36ec976c8e6ebd9299.csv',
#  'train/5217e67601888b19d17f.csv',
#  'train/934801d3eef2859781e9.csv',
#  'train/44dd290ed7525d949238.csv',
#  'train/a5869f2f354e984faa4f.csv',
#  'train/2e30a883a001ccdbcb3f.csv',
#  'train/38d45e24ee495248792f.csv',
#  'train/6e12de66c9b6d9a68025.csv',
#  'train/0bb90b3ad8f2efc4e2bb.csv',
#  'train/dd5823570f01644b4c53.csv',
#  'train/81daade083741986cc97.csv',
#  'train/c59909533f72e38acf15.csv',
#  'train/6d8e57bffeed1b4f52d3.csv',
#  'train/1d944946c26ad2c53c75.csv',
#  'train/0e576bed5031a3abb758.csv',
#  'train/581c949015af35485f7f.csv',
#  'train/2e269fdd1ca3bb8a39d9.csv',
#  'train/eb280374f1e7ec3e7086.csv',
#  'train/78d2bef2ce8e2732da4b.csv',
#  'train/1ca5becdf49fb9195c7d.csv',
#  'train/946e2c8dae0f79a3320d.csv',
#  'train/984bd2605fbe84ed6d86.csv',
#  'train/fcc6b62212326c5bf420.csv',
#  'train/7e31fc108e356482bd16.csv',
#  'train/9a6959ff1020de13062b.csv',
#  'train/564c70918a8e7a9e51a2.csv',
#  'train/279575fda08061cd41e7.csv',
#  'train/82ec3462f6c3d6593ba9.csv',
#  'train/9b7543aa88a45c738549.csv',
#  'train/4edd3cf65e283194cdba.csv',
#  'train/9b3f199287263f53bde6.csv',
#  'train/51f486542a96c9887b17.csv',
#  'train/63c5a6cc99d710712332.csv',
#  'train/96b9150cd848ec8043b5.csv',
#  'train/94247ef2fcfbcfb1fa92.csv',
#  'train/5cdc5e20423498a6186d.csv',
#  'train/41c6010f59b1c1ec1174.csv',
#  'train/7fcbbd8a626d002fe001.csv',
#  'train/711d872eec06a674d8a8.csv',
#  'train/5b33e6780f3b79768d6b.csv',
#  'train/b62f3042ad51c8cbb978.csv',
#  'train/546a0e9d3fca8f2aa0cd.csv',
#  'train/1bab32e14ece645afcb7.csv',
#  'train/d4ef73d9d83d3dbcfecf.csv',
#  'train/eab46e5d0c391f1ea4d4.csv',
#  'train/cd6eb510705d9fb4f918.csv',
#  'train/d1dd2236b2297f682917.csv',
#  'train/c61f8a076cdc141013aa.csv',
#  'train/755b05b02584a83e33dd.csv',
#  'train/147f5c18bf57174c2f19.csv',
#  'train/818342032032f7d2c325.csv',
#  'train/d9773394f827f6c4f52a.csv',
#  'train/2c4cb44fdbad3a4075a5.csv',
#  'train/f10ba73bb4c7744ccfe9.csv',
#  'train/8ae6b1df5e727eaf01d9.csv',
#  'train/0f06530a3f26a3add41b.csv',
#  'train/fdaa72619a59292d1c04.csv',
#  'train/53855b930cc13b3da079.csv',
#  'train/b4fc8c169c596c8cb57a.csv',
#  'train/d2640c2597ec06006cef.csv',
#  'train/6b62736b17fd49927b91.csv',
#  'train/de7e728f03dca86f0782.csv',
#  'train/b5023874fc1b3c090428.csv',
#  'train/2c54533e36c89468142a.csv',
#  'train/21e511fb8bc2cb789f83.csv',
#  'train/fa5979704821986a1f74.csv',
#  'train/ff9c85def1d705207445.csv',
#  'train/bf560f4cac8c16af7676.csv',
#  'train/a142122303825876f57b.csv',
#  'train/492cc2d843c007161a91.csv',
#  'train/2dfab19e1c09a6379e8d.csv',
#  'train/91c1301c3f9defe5f8a2.csv',
#  'train/c1d7c77cb3a7de1a4298.csv',
#  'train/c2b1ba4c663a99394b11.csv',
#  'train/f1e9577fdf6bd581c4ca.csv',
#  'train/cb3614ff6d9ee85e6d17.csv',
#  'train/37505f73bf16313df7d8.csv',
#  'train/105ef2b10ac9128055dc.csv',
#  'train/770ee1a80ebd2aa5107d.csv',
#  'train/b5c85da31e0854083439.csv',
#  'train/8ad133b45a99a4451837.csv',
#  'train/7e66a3f09c750b0fa623.csv',
#  'train/3e1b300c7712aad66387.csv',
#  'train/bf75069a3321c05a3fd3.csv',
#  'train/e8ba1d13cd9d087f241e.csv',
#  'train/2f663ecb7fa10393cefd.csv',
#  'train/af15df1a34ce17e69617.csv',
#  'train/e4327e69de3f088325b2.csv',
#  'train/cfd7d901bc3aac44535f.csv',
#  'train/ce6a56a910f3611c2517.csv',
#  'train/ed119c91a9bd6616a4d5.csv',
#  'train/9fa8e06b7af99c4575d8.csv',
#  'train/a5f983837df07b6c8ff8.csv',
#  'train/6247274ecddbe254a291.csv',
#  'train/b664c648c53af0f8e44d.csv',
#  'train/72e59c2243741b09a410.csv',
#  'train/3b033821095082a6dc60.csv',
#  'train/ca6eda5e03ecfc0642d0.csv',
#  'train/f69b4fd8ab5b606f7fa9.csv',
#  'train/47532525a0fb47076c66.csv',
#  'train/5ec08d6679210fa1f840.csv',
#  'train/a137258e8bd560e36f82.csv',
#  'train/65c28fabf163aae16db1.csv',
#  'train/99226dd6fcd856ec533a.csv',
#  'train/3ceaa7dbdf5805a59ab8.csv',
#  'train/a3dd0ab835cc6e3bb1bc.csv',
#  'train/538e9a8e44603f0ab4c0.csv',
#  'train/80c446087d858e82ba44.csv',
#  'train/a02149aed967e6e2d552.csv',
#  'train/9501cdbb0089bb449437.csv',
#  'train/742ab52264c8cd10b45e.csv',
#  'train/3dc44a1a75630d7a2aae.csv',
#  'train/8fb72fd18de9aef89ee2.csv',
#  'train/f6e47145270057957b63.csv',
#  'train/31fb58f4379a7cba8b77.csv',
#  'train/fba5b4560d61f0cf56bf.csv',
#  'train/123249484893c6da770e.csv',
#  'train/c3f077ede0eb6d7b8e91.csv',
#  'train/b87cbea04abc5104f581.csv',
#  'train/a16ced64fb65575ce8ef.csv',
#  'train/3d5c8d5f586dc4729b75.csv',
#  'train/1be5020e702499211355.csv',
#  'train/b0025919a47539041e5d.csv',
#  'train/34c27594335e38989e34.csv',
#  'train/234bd62c95159d4b4961.csv',
#  'train/4e811ea6e92fce799a0f.csv',
#  'train/b8023c6c2ccae26e5302.csv',
#  'train/67415399dd3d4647bdce.csv',
#  'train/a4c03c1f4e2124977351.csv',
#  'train/6aef6fdde93740d79a38.csv',
#  'train/c0803c790b4b4a089a25.csv',
#  'train/2c9921ec6236371f9b4d.csv',
#  'train/66724848a418dca3da70.csv',
#  'train/f44be5f699064c24ca1d.csv',
#  'train/5933f66d13de89b37c80.csv',
#  'train/1e0c3237ade3ce634ccc.csv',
#  'train/8f809eb7b25f38c1942a.csv',
#  'train/46dba5ce124a3fe3a963.csv',
#  'train/63e885125f9594ccf8e9.csv',
#  'train/3816dcd1feb4a01c78c2.csv',
#  'train/13189968f9621a82fd36.csv',
#  'train/0414b70a2c875ff40706.csv',
#  'train/0bfc086c6bce71cd8b51.csv',
#  'train/b8ba58faac282c41bb25.csv',
#  'train/ff573940628966b92157.csv',
#  'train/0fb5a38bcfe32394237b.csv',
#  'train/6159e4bbf06dbdcae11c.csv',
#  'train/5603dc5caceaaed64072.csv',
#  'train/61ae0cd724ec857121e5.csv',
#  'train/56ce23fdef0d5096a093.csv',
#  'train/e72c2d20c307fb1d2853.csv',
#  'train/2e069328bc72211f303b.csv',
#  'train/c8eae85a2d4cacace300.csv',
#  'train/b819f62ad0223149c965.csv',
#  'train/fd64d8e893b6ca0790c3.csv',
#  'train/d32f8c67ea830b49fa70.csv',
#  'train/ce9d2eae7e70e3e552cb.csv',
#  'train/fec87fc5c260f5ac21a2.csv',
#  'train/6adf6c63b52c8982b47d.csv',
#  'train/7125b78fc681c323fdf9.csv',
#  'train/282351b51cebcc269605.csv',
#  'train/f1f529d25d0588eb76db.csv',
#  'train/558df5deb7c15a6b8665.csv',
#  'train/a24c9121deb9aa6f7b49.csv',
#  'train/8a447784011fc6d302e6.csv',
#  'train/f473ef8589e0d5a74d00.csv',
#  'train/3672c27b020c0628755c.csv',
#  'train/dc8d3223c717075ccfbd.csv',
#  'train/9bcf258d4b3e5451f720.csv',
#  'train/53b225ec08301694f52f.csv',
#  'train/ca3d32709eee8a79e982.csv',
#  'train/a7f22fb59281890bac43.csv',
#  'train/23f2ed6fcb6767ae06a8.csv',
#  'train/5e1323e7c9ab6422fe5a.csv',
#  'train/f0b979231ce72ba057d1.csv',
#  'train/124e032abf55faa04d9d.csv',
#  'train/9764282df683de2d7ddf.csv',
#  'train/705543c99fef8963627d.csv',
#  'train/356a8e453c79855a8b3b.csv',
#  'train/86e90c5133fd813a8b8e.csv',
#  'train/1f6f271c2318bbf5015a.csv',
#  'train/b95042bcce0f1cddeef9.csv',
#  'train/7c5048d6ab62921324d6.csv',
#  'train/4fc6721dca6186d1346e.csv',
#  'train/af407f614ee639a4557d.csv',
#  'train/e209686e90b136c024ce.csv',
#  'train/4bcbf46aa95b1c4692ba.csv',
#  'train/d7794f5ee34daab20ce4.csv',
#  'train/a896d3962f52d22db3ea.csv',
#  'train/1d7a51fc1b7770435ca8.csv',
#  'train/89f70c61608834a262b2.csv',
#  'train/5c47657dcb0853806d59.csv',
#  'train/c7ed25c851862a0ec153.csv',
#  'train/487b4613702445a35c56.csv',
#  'train/6215016166557c61ac73.csv',
#  'train/1c4320bf4f9ed052506f.csv',
#  'train/ad57c46e2c0617541ce2.csv',
#  'train/9eeab9796b9e52a0d408.csv',
#  'train/94858312810aad6eb96c.csv',
#  'train/b9a6d0cc71ec6452629b.csv',
#  'train/487b96d72bf1133c28d6.csv',
#  'train/24d271ce8c312fbd4432.csv',
#  'train/20b956e2200f6d51dbad.csv',
#  'train/f7abb42fbdc93ab67305.csv',
#  'train/03a1ba177aa1c0aaba25.csv',
#  'train/da6e1934c7147a9e067a.csv',
#  'train/d656f40c128ed64922bd.csv',
#  'train/63a219821722320fcfe7.csv',
#  'train/56f88b89207aee786b25.csv',
#  'train/2aa9f5ea33601778428e.csv',
#  'train/855ca2332ec8c90b1421.csv',
#  'train/e0621a4129ce0e3519e1.csv',
#  'train/e86454f7f60d96bfdbf8.csv',
#  'train/f30310f366a70302402e.csv',
#  'train/69d0c0d1b3a2308fa7fe.csv',
#  'train/eb77ede8c4528a89bd23.csv',
#  'train/c8d8bb8bc95cc4af6fa7.csv',
#  'train/0dfee2e5f29fd96fc955.csv',
#  'train/36edccd407ec35c7511a.csv',
#  'train/bd92c27d4aeb8cf41dc4.csv',
#  'train/781e21ae586dd790dfbe.csv',
#  'train/b703b05907c1f2a3325f.csv',
#  'train/a595aa939ad27e912c68.csv',
#  'train/c14f6bb507d2cecf833e.csv',
#  'train/768316f876209ebe34d1.csv',
#  'train/cb3de903571a156e684e.csv',
#  'train/bd30132ee4511a33f049.csv',
#  'train/fa28cb5d51abfa7ae011.csv',
#  'train/b7fbf21e25f93e1c3152.csv',
#  'train/339f927cc8908a2a2411.csv',
#  'train/788dd44e365f934b454a.csv',
#  'train/899385f910a8619e1e27.csv',
#  'train/e6d78104d18a6fd9ff47.csv',
#  'train/2bd5aaa526559ffdd5f3.csv',
#  'train/8ea39bd492790eec4033.csv',
#  'train/49bd7ae316580b130897.csv',
#  'train/6c1da53f1ff9715705d8.csv',
#  'train/a3d4272c3d3ae509fbe2.csv',
#  'train/4755de1844e5572b5305.csv',
#  'train/bd761b445f48a5f160a4.csv',
#  'train/3a736c50a2df8562b982.csv',
#  'train/767388413a0a69155232.csv',
#  'train/9011c0b6d95c40cfee2b.csv',
#  'train/212e157053a827bb0bff.csv',
#  'train/04981953f6db6803fb94.csv',
#  'train/7f614436e215b1cc3a59.csv',
#  'train/20474000a9f90240672a.csv',
#  'train/d1096c5b3e1b7be1a18c.csv',
#  'train/e508024032a1b1ad2da3.csv',
#  'train/5da1b74ae74d94977cb5.csv',
#  'train/71fdaa6e2a5b2629a779.csv',
#  'train/a4a18272d32f67a23352.csv',
#  'train/5536a19a19f3ad73e04a.csv',
#  'train/42389f0fd2dc761f2993.csv',
#  'train/eb62169bf7521fe24d64.csv',
#  'train/2c8d8f924460bcc58cfe.csv',
#  'train/2be3a68d4c0a1c16bc10.csv',
#  'train/ceaaf226078a22e7f292.csv',
#  'train/391148095d3ea2087a28.csv',
#  'train/b5b68fb7230189a76d21.csv',
#  'train/96a34ddbedaac3eb3be1.csv',
#  'train/4a55c05164b2b6c21011.csv',
#  'train/2d359101f7c9d986907d.csv',
#  'train/4d4dd0fff9372ad17a8c.csv',
#  'train/d4ecf73581491ec90325.csv',
#  'train/277f4169e448ff57c6fc.csv',
#  'train/659caef258d987c81730.csv',
#  'train/b624f1fef07fd1380c84.csv',
#  'train/ac585bd52bd3c75028c3.csv',
#  'train/b372f82f01d95548bcd8.csv',
#  'train/cc7664b623276b688c4d.csv',
#  'train/910cf38d94cc6109666f.csv',
#  'train/70378ed3df6b649e129b.csv',
#  'train/60e016d0b3fe8976e712.csv',
#  'train/3eb904d37a1261199c74.csv',
#  'train/15368d3a4533f836ae40.csv',
#  'train/ce38cbe71e59dc9d5e54.csv',
#  'train/1b5ab556ab748fcdf9ea.csv',
#  'train/18579a4fa9c547ca2ba3.csv',
#  'train/85e6573af6f2fc83df17.csv',
#  'train/c96a4cbd579354a7a180.csv',
#  'train/09d097faf099337ed15b.csv',
#  'train/2f9d46745874f908b7ab.csv',
#  'train/fa00dbcf6ce0f3e151e3.csv',
#  'train/e49fc10e9ab1f63ee68f.csv',
#  'train/883a52557886091ea147.csv',
#  'train/9a05e820ef97d9f42957.csv',
#  'train/3f6662d8a8446a1ed339.csv',
#  'train/b8d58e210b070130a504.csv',
#  'train/3fbf6d0b4266d7dccf7b.csv',
#  'train/c181d77ab00807ac0107.csv',
#  'train/4f626b9bceb429ffb795.csv',
#  'train/3390c60564900bcb32d9.csv',
#  'train/a6379b5b6ecc5879d91e.csv',
#  'train/7d353d490b4a80f43175.csv',
#  'train/0aa633b67a870b592318.csv',
#  'train/c67769d18f12ebf66118.csv',
#  'train/42bb9a87548c8767bda1.csv',
#  'train/ad89a85f1602211b1dd1.csv',
#  'train/46c59868c10747529d06.csv',
#  'train/cfc33d7a45a6baa9d532.csv',
#  'train/bb4dd5b09680e003129a.csv',
#  'train/4625b051c561fe1d6e49.csv',
#  'train/a23ad58def268456aabe.csv',
#  'train/6d652161498a3204e3fa.csv',
#  'train/fdbf899449d216027325.csv',
#  'train/19c65e5b89d4034da85a.csv',
#  'train/22f3d5ad7bf1661716da.csv',
#  'train/6736ef340817d219f765.csv',
#  'train/9583d907b7bebe968682.csv',
#  'train/a1b0bee0a1a7c2e3e7a5.csv',
#  'train/f7ba04728a91fa65f25d.csv',
#  'train/e14d7ae28d5c26a956d8.csv',
#  'train/596192488b0a5b7ca060.csv',
#  'train/21bf6e1c94461da23a82.csv',
#  'train/644205232c19d47982ee.csv',
#  'train/bff890859f97392a1298.csv',
#  'train/0a56673739e7f627226a.csv',
#  'train/bd49c5c06e8bfa3fff51.csv',
#  'train/7215013fd359aecddbd9.csv',
#  'train/af9b8d8683d99d3dfdad.csv',
#  'train/5d9716e95fc71a2fba9f.csv',
#  'train/4725024d9661a93c8fb8.csv',
#  'train/8fea490f823e9f0a77bf.csv',
#  'train/c45b94e80bc6bb7cd2b7.csv',
#  'train/556ecb61e5677c371a51.csv',
#  'train/a87bf629875054ea0b60.csv',
#  'train/b05db8d8489699ffca0e.csv',
#  'train/94b95093bb8b9bcf6184.csv',
#  'train/f0a08ccdb928467c7681.csv',
#  'train/1c6009081eca82c82731.csv',
#  'train/32ce2402e2c698b9ba45.csv',
#  'train/40cfcf5f7be58573bb35.csv',
#  'train/f208370f0db776314302.csv',
#  'train/761c61c406392be12464.csv',
#  'train/a9a0f54d5483699ad619.csv',
#  'train/65437a4f8fccc2bb6d31.csv',
#  'train/e48ab5ad541388423bfc.csv',
#  'train/7cb453eb730b30556a96.csv',
#  'train/4c5a665ff52f144576a3.csv',
#  'train/0e71daa146972c2b15ae.csv',
#  'train/46001cc1619757da512b.csv',
#  'train/73f3b4de6fbb98bfa903.csv',
#  'train/4a9fff920ea4bcf63fa7.csv',
#  'train/506e9b5983125e7c64ec.csv',
#  'train/c18249449194da8d1bd4.csv',
#  'train/2964cbae6d20012828f6.csv',
#  'train/8365a5277762639e62a9.csv',
#  'train/fc031b9f3776a6df1157.csv',
#  'train/d680a484e4512fbc116e.csv',
#  'train/9ea28e11b1e5db2fad60.csv',
#  'train/16bea26e61191ecf7c60.csv',
#  'train/55a6aa05878742ee0a7d.csv',
#  'train/e35649f5a43a18b4ae7a.csv',
#  'train/7c897de1a4ba938a5408.csv',
#  'train/ee874820b415ed72e369.csv',
#  'train/07eb84a530676b0f9978.csv',
#  'train/546ecda307c782a28be9.csv',
#  'train/06be9a8a182eb04f66ea.csv',
#  'train/5cf979c57b135c53e76e.csv',
#  'train/ad7726a10eefe6cae744.csv',
#  'train/c78ffe643116fc76d134.csv',
#  'train/72649a723ef1f85b101f.csv',
#  'train/3491d515ea5ff2ca52fd.csv',
#  'train/12435cf970f06dbaf30f.csv',
#  'train/5b8126a33b6e1687745d.csv',
#  'train/1aee2d397250ea8034d8.csv',
#  'train/9d6bb7d549c1069e48cc.csv',
#  'train/dc326fe7fd0ad5392dd2.csv',
#  'train/680600cce37fd5fdb7ac.csv',
#  'train/b48ee968a081ecde554d.csv',
#  'train/99a6c4b3650b4664ff12.csv',
#  'train/9fd98bbe3b382afd3f5a.csv',
#  'train/c464e9f5c5820ae0845c.csv',
#  'train/bdf0025f28736d606c1c.csv',
#  'train/2cad7fed3c9cb5421702.csv',
#  'train/7811cb9c7296a4e70be0.csv',
#  'train/5fa4378fece8e41828ec.csv',
#  'train/faf8e728931ea3106f80.csv',
#  'train/cc8ca66b7c84c53bbd98.csv',
#  'train/673516e69c4618f5473a.csv',
#  'train/cc88fe65aca8a4f4c79b.csv',
#  'train/72d82225b87b0e19bf63.csv',
#  'train/c7c676f491f170c728db.csv',
#  'train/16c9b75f4dc96846b63b.csv',
#  'train/209f2d0af319c9573669.csv',
#  'train/94b0e55b7845d1aeee80.csv',
#  'train/39ada448a48b2814c07e.csv',
#  'train/88a2b87dca8f0af1d7f8.csv',
#  'train/36678afb0522bfc271e8.csv',
#  'train/94f541423fcb9764f32c.csv',
#  'train/96e8d98a1711dc19c2e4.csv',
#  'train/a710eebc23bd6a88aa9a.csv',
#  'train/8af008f104c574a5481a.csv',
#  'train/0fcd6cd456e40d211734.csv',
#  'train/95ee6efe2d30b334da95.csv',
#  'train/c942b5429181e4c2aea3.csv',
#  'train/0faa4fab88146a7c7b34.csv',
#  'train/d52da6504fd5a689c23c.csv',
#  'train/fb6961acf8c158129ab1.csv',
#  'train/e6b750e6d466d88f117a.csv',
#  'train/bd6e0ab403f7aea9852b.csv',
#  'train/3befe489150effb961b1.csv',
#  'train/3d25fd25b52ce7fcd7c6.csv',
#  'train/b9fa736305a1b900a499.csv',
#  'train/dd4b421699f86b294f3c.csv',
#  'train/5842802d749308feec72.csv',
#  'train/a1a2fa356c1424f62dd9.csv',
#  'train/f0182996345fbb70666f.csv',
#  'train/b8c15c0a8ccb84480199.csv',
#  'train/561d7f334d32ca89c08c.csv',
#  'train/0af5375d6ae7efd2091c.csv',
#  'train/f99652a1c096d3a8cdf6.csv',
#  'train/94bd823e84cc41111273.csv',
#  'train/924ab1df88d1b30f0d86.csv',
#  'train/3e5693071f62bbf4d491.csv',
#  'train/66f1ab649dd95a69aab3.csv',
#  'train/13588fbd14b3bc44ec71.csv',
#  'train/0acdb336f2fa2fa46b8c.csv',
#  'train/c3ffad2e2ed6037ed32f.csv',
#  'train/04f4ee49de378a04bd51.csv',
#  'train/e02159d9ce2cedb38aa6.csv',
#  'train/0d28a49c1c4e6802ed8a.csv',
#  'train/9b62c3c73da76ee7ec5f.csv',
#  'train/6b948530ac726e45aca8.csv',
#  'train/d352f2ed976c0a21fecd.csv',
#  'train/91abc753fdfdafb57cb9.csv',
#  'train/d850b497dde36ffb37fa.csv',
#  'train/32b040433c0510a7fb2b.csv',
#  'train/d23562b46f7096819f50.csv',
#  'train/4d8fc72870ad2371c9a9.csv',
#  'train/74641603d5dd3a6fe84a.csv',
#  'train/a70e01373405d07df226.csv',
#  'train/792001efe31d0eb5e5d2.csv',
#  'train/8b01026475395652c6f4.csv',
#  'train/c0ce28b5fdb9434cc6bd.csv',
#  'train/2fbb0c4b77d90b17406e.csv',
#  'train/20140dc0df8d335b3846.csv',
#  'train/14c07944ed578cd91f17.csv',
#  'train/7710b47555c16e60ee9c.csv',
#  'train/93c89d62530b51df2b4a.csv',
#  'train/a1c8b2f0410647d1ce4c.csv',
#  'train/e0d8285c04d5be68f1ff.csv',
#  'train/d4b098e9d3c1097bce4f.csv',
#  'train/4f38e64eed6ba8c4bf35.csv',
#  'train/fe6aa4a9b3ba63e01434.csv',
#  'train/9026e23a8885e954ddd9.csv',
#  'train/877ec373151c14b1d097.csv',
#  'train/87ce1408ac94168206da.csv',
#  'train/ff8a76386d404c3d09c6.csv',
#  'train/ba4d8519d25d017a0333.csv',
#  'train/cf017a1bb68bad09f824.csv',
#  'train/655fb19ee0f3f0b4f1f6.csv',
#  'train/830f26315a6ec66aba3c.csv',
#  'train/d38cd985e842403992f2.csv',
#  'train/6c15c1763f920a2fdb15.csv',
#  'train/8681072a6070e156983b.csv',
#  'train/48aaf589be32f91e2ee8.csv',
#  'train/b4f9f987e666f7ad99c3.csv',
#  'train/f6ccba8359468a18c85b.csv',
#  'train/f0829b6b4d0cbefead68.csv',
#  'train/a688f4ff93caa1b72d23.csv',
#  'train/051386ff6c7ba31070a5.csv',
#  'train/c0241496ba5140193e17.csv',
#  'train/881d2f57ca11422d0c51.csv',
#  'train/3d9ea483c4c246821cf9.csv',
#  'train/dafec28dfa5acfb9e9e2.csv',
#  'train/e9e7c99ec701e8b2b3cf.csv',
#  'train/6e5ea0971e6ee13951ea.csv',
#  'train/5d9076d36b4130c672e1.csv',
#  'train/c0fdb7f8cc4413320f41.csv',
#  'train/18011b479293d7b5d3a6.csv',
#  'train/106f28e7f2bfa4a7e1a0.csv',
#  'train/d5d2853f6780d1e020b3.csv',
#  'train/dae103e7ecba38658258.csv',
#  'train/0469eae8341183fe1c31.csv',
#  'train/1149b399a480bb599ea1.csv',
#  'train/a45f0d8fc3e0952ce03f.csv',
#  'train/ded0c85706f81980210d.csv',
#  'train/02d951c4e7aa0555a8a7.csv',
#  'train/110d4a7dcdd417511cfa.csv',
#  'train/5329f3f8bc3fbba1e276.csv',
#  'train/309f7dc1677e0697939d.csv',
#  'train/27b553e8ea6b0c30c2ad.csv',
#  'train/5767e300dd3a929fb6c5.csv',
#  'train/e38337fcc21960421403.csv',
#  'train/22a39725bc6c0f3c335e.csv',
#  'train/dc1bdfd68c3c71bb049d.csv',
#  'train/95edf6c44f15940ca061.csv',
#  'train/7bfb3bc94f667f6949a7.csv',
#  'train/0d5f8fd088521c768227.csv',
#  'train/9fcea80c4ce99a00ccf5.csv',
#  'train/f5ef60f0720e2802bbc1.csv',
#  'train/b2c025cc02de90d3aa4c.csv',
#  'train/642b3869c7064e81afb7.csv',
#  'train/58c1a32cf18e8a44921e.csv',
#  'train/90743b5ee847faa00206.csv',
#  'train/4dd2233462838ca5178d.csv',
#  'train/19b7204d8ffee2b3b009.csv',
#  'train/078b743e641cc6601d4e.csv',
#  'train/649c41340b818bf35682.csv',
#  'train/41dfba33cd18eec4b17a.csv',
#  'train/dd64c4c88279afb8d6e0.csv',
#  'train/a4080cf40fbefe189345.csv',
#  'train/1d4e4133d7f19717ed48.csv',
#  'train/9792efae79e7ad183466.csv',
#  'train/b49a4b05706450965fa8.csv',
#  'train/b10d4256e3c0ab98807a.csv',
#  'train/4e55d78c66bfafdbebb4.csv',
#  'train/99737d4e79878e11dfec.csv',
#  'train/dbc08e07c52e161ff599.csv',
#  'train/806c289fe1e3fcf1765e.csv',
#  'train/f971d176a647e38f1493.csv',
#  'train/238599605cbfc2d4eabf.csv',
#  'train/7649469b00cbdedd8a9d.csv',
#  'train/bcc915a05856db7c0590.csv',
#  'train/4c661aac86803bfe84cd.csv',
#  'train/e96ccd7595889179eff1.csv',
#  'train/e205fdf5685950725533.csv',
#  'train/c0078af91762fae81f8e.csv',
#  'train/c9db824c639463559765.csv',
#  'train/403ab3b17849ac053507.csv',
#  'train/b807d1e4049699e60f75.csv',
#  'train/6815876be861429d5f57.csv',
#  'train/ba9ae1911f34ff05cd06.csv',
#  'train/e617dcbc075c60030240.csv',
#  'train/d20f3a21c2d55610645c.csv',
#  'train/b54cf3eb11f31aba2f72.csv',
#  'train/5fe068ea23a39ce0b722.csv',
#  'train/cee2c97ab4c185f89e13.csv',
#  'train/0b7c1297e777711f6b03.csv',
#  'train/b399bcc70a0e89a87fce.csv',
#  'train/5e595f98decdcfe8f2b2.csv',
#  'train/bfa70375e3143e0527d5.csv',
#  'train/3e130d42eb382c37e076.csv',
#  'train/64ec9e88ce7952253d30.csv',
#  'train/7272abc511dc39b956af.csv',
#  'train/85f72764e9d86148bfaa.csv',
#  'train/9cb28fea2aeba7976832.csv',
#  'train/9b7fdcf6315de0c22f5c.csv',
#  'train/9a6655c7fa19a9ba2cdf.csv',
#  'train/33d4034c146b0657d9f9.csv',
#  'train/5bbd06ffd447e60692bf.csv',
#  'train/11151c195a23d24b6123.csv',
#  'train/3bf3bf6a1b43fe539d69.csv',
#  'train/e648787f1053e63448f0.csv',
#  'train/319092c209f5153ea51c.csv',
#  'train/8018ace6ed5517388f3d.csv',
#  'train/0c2b58d01a9bdfb6b8a4.csv',
#  'train/d714950b112fdab0dbb5.csv',
#  'train/38eecac83f076599303a.csv',
#  'train/e2ce9e19292c8a993686.csv',
#  'train/6823b01b17ef4326f8bd.csv',
#  'train/71654a29da65b33470af.csv',
#  'train/1760a5ec89cf66ca6f1d.csv',
#  'train/e28f06b006f76b357211.csv',
#  'train/ed066bb58e4fee95eaf3.csv',
#  'train/3f116318e1d27aece037.csv',
#  'train/f1cab49709babeda4f87.csv',
#  'train/817c2517725e621d34a0.csv',
#  'train/7b5d3bbba3c7391352c9.csv',
#  'train/473c660d5d1d8528062c.csv',
#  'train/a1c9cd47afbc70e1801f.csv',
#  'train/a27f82b047c4fdb7ae4e.csv',
#  'train/2497be312bbfba005d9e.csv',
#  'train/cf6ef1b9bc6d02eca4ca.csv',
#  'train/9a380d0f3eb979ca6bb5.csv',
#  'train/7d69e963490a7fd52f96.csv',
#  'train/4a48a055050afbe88996.csv',
#  'train/8d7a0f4b73b6ad5830d1.csv',
#  'train/58f3ac0a4d03be46ff13.csv',
#  'train/9cb65f289b43a21c6516.csv',
#  'train/fcdae8d1a3ec163f0cab.csv',
#  'train/398f768f52db382bb822.csv',
#  'train/62fd1415a863e67f090f.csv',
#  'train/c1210ae1707c81350f69.csv',
#  'train/bcf5dfb672c4dc13aff8.csv',
#  'train/ff4577d29ef116edaf60.csv',
#  'train/a19815e4b62360699df6.csv',
#  'train/b89632d069e97b1042dd.csv',
#  'train/be51be1f099820b3f141.csv',
#  'train/92cc8da24f8ed79f19a6.csv',
#  'train/1bce4f3da3da8049bf51.csv',
#  'train/23e9f1126bd2a66156d7.csv',
#  'train/405837385d6ca046f0a4.csv',
#  'train/e5f33706d94fedce1b2a.csv',
#  'train/ad2e8024b09e9f9f2698.csv',
#  'train/19309cd3e21859c9aad3.csv',
#  'train/795f37843061438eb06a.csv',
#  'train/a0bd9bc2d34fe16e8a7d.csv',
#  'train/22f7b4912486629fa297.csv',
#  'train/32d1df11dbbee663050a.csv',
#  'train/e7c25c4e532d94ba94fd.csv',
#  'train/e42b259471b99cacb4d4.csv',
#  'train/3bc8d58d4732778888af.csv',
#  'train/b5768a7b16528efbf36e.csv',
#  'train/82bfe65d8db3d14e59ab.csv',
#  'train/6cf338ab398c19d1d969.csv',
#  'train/9ee4cbd3c86dced95d6d.csv',
#  'train/4d7284c04e5b5d774f40.csv',
#  'train/535543da0f98e3679b0e.csv',
#  'train/22d564171c25672ca276.csv',
#  'train/ead30499be5a7f3a21b0.csv',
#  'train/7be9b749f544b14a0ee7.csv',
#  'train/5d8196567c1d080d5dbb.csv',
#  'train/b49b797edca052e10b1d.csv',
#  'train/bd7a4b68ada014a17ba7.csv',
#  'train/a7054600e1196a1f5934.csv',
#  'train/238890df91fd81473d32.csv',
#  'train/359a3633fdc4fa20bb0a.csv',
#  'train/d316c341a9f2bf688f27.csv',
#  'train/941021344dd1961e0974.csv',
#  'train/d8ec04ff6cc67764559c.csv',
#  'train/21c2046f387534638559.csv',
#  'train/673d78921ffbc698efdd.csv',
#  'train/cef70d211ab6c23a58d0.csv',
#  'train/2d29869b06bed8bd09fd.csv',
#  'train/50135183c4a7e959af39.csv',
#  'train/23d3266a1e6052497fbb.csv',
#  'train/2b2c5f461b2e7e04d39e.csv',
#  'train/fd799c71f2fa546777e3.csv',
#  'train/28607dba589a91b59338.csv',
#  'train/0c4c47ef73f6ac9239c3.csv',
#  'train/4061174a848cce01b182.csv',
#  'train/95be6970d25cfc7e8cb4.csv',
#  'train/98f930f81c8d0f1f032c.csv',
#  'train/fab8a03b3be046bda608.csv',
#  'train/55ce29fc4e177e857523.csv',
#  'train/6b97515e8c13ef8bd664.csv',
#  'train/1206dfd416501351398c.csv',
#  'train/620b71882ffe5d7a3142.csv',
#  'train/fafd8c1686e53157f324.csv',
#  'train/5579a8afb31fea64c73e.csv',
#  'train/732b3d0d5e8b39596cae.csv',
#  'train/71c5a3cb825b42657c06.csv',
#  'train/7d5c4c5679546904173b.csv',
#  'train/64a0374389bacafe46be.csv',
#  'train/c4979a933c43f16ee2f3.csv',
#  'train/fb4234d5631971c5cfca.csv',
#  'train/e3bbee28bbae288c571f.csv',
#  'train/c098180716afc7db8e3b.csv',
#  'train/11fbc4c7d1712a62ce89.csv',
#  'train/bc28faba84ed39c5f2ed.csv',
#  'train/eae60bcd36522f74689d.csv',
#  'train/fece8a2e57d869c3e36a.csv',
#  'train/3e144505e13418a5872e.csv',
#  'train/7f57ea000d3ad0d4727e.csv',
#  'train/35f7ea67ad5247c52c22.csv',
#  'train/00fb58ecd675062e4423.csv',
#  'train/f760be00bdef803304c6.csv',
#  'train/333aade24591396dd236.csv',
#  'train/188284d313d7b8307821.csv',
#  'train/8b9d82754839ff714b4e.csv',
#  'train/2b60cfe9c4949f413a8e.csv',
#  'train/034308a074619b08c67f.csv',
#  'train/d55dbf7027399d95a0bf.csv',
#  'train/8387c0c7580a0e43e3fc.csv',
#  'train/d907033a657da6805409.csv',
#  'train/739149d635e18e73fe44.csv',
#  'train/50b61bb74d1e59579a35.csv']
